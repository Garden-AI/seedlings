# %%
# !pip install garden-ai

# %%
from garden_ai import GardenClient

# %%
gc = GardenClient()

# %%
wisconsin_garden = gc.get_published_garden("10.23677/67r2-yh86")

# %%
import pandas as pd

# %%
def get_test_df():
    import io
    test_data_string = """temperature_C,wt_percent_Cu,wt_percent_Ni,wt_percent_Mn,wt_percent_P,wt_percent_Si,wt_percent_C,log(fluence_n_cm2),log(flux_n_cm2_sec)
287.0,0.04,0.74,0.6,0.012,0.23,0.21,18.664547962246548,11.165741355311178
287.0,0.04,0.74,0.6,0.012,0.23,0.21,18.664547962246548,11.165741355311178
287.0,0.04,0.74,0.6,0.012,0.23,0.21,19.641969597702058,11.160891757727123
287.0,0.04,0.74,0.6,0.012,0.23,0.21,19.641969597702058,11.160891757727123
287.0,0.03,0.56,1.4,0.005,0.31,0.13,18.664547962246548,11.165741355311178
287.0,0.03,0.56,1.4,0.005,0.31,0.13,19.641969597702058,11.160891757727123
291.1111111111111,0.15,0.52,1.32,0.01,0.2,0.21,17.861534410859036,10.389599950323971
291.1111111111111,0.15,0.52,1.32,0.01,0.2,0.21,17.861534410859036,10.389599950323971
292.22222222222223,0.15,0.52,1.32,0.01,0.2,0.21,19.012837224705173,10.966255912381982
292.22222222222223,0.15,0.52,1.32,0.01,0.2,0.21,19.164352855784436,10.93719246682784"""
    df = pd.read_csv(io.StringIO(test_data_string))
    return df

# %%
test_df = get_test_df()

# %%
test_df
# Out:
#    temperature_C  wt_percent_Cu  wt_percent_Ni  wt_percent_Mn  wt_percent_P  \
# 0     287.000000           0.04           0.74           0.60         0.012
# 1     287.000000           0.04           0.74           0.60         0.012
# 2     287.000000           0.04           0.74           0.60         0.012
# 3     287.000000           0.04           0.74           0.60         0.012
# 4     287.000000           0.03           0.56           1.40         0.005
# 5     287.000000           0.03           0.56           1.40         0.005
# 6     291.111111           0.15           0.52           1.32         0.010
# 7     291.111111           0.15           0.52           1.32         0.010
# 8     292.222222           0.15           0.52           1.32         0.010
# 9     292.222222           0.15           0.52           1.32         0.010
#
#    wt_percent_Si  wt_percent_C  log(fluence_n_cm2)  log(flux_n_cm2_sec)
# 0           0.23          0.21           18.664548            11.165741
# 1           0.23          0.21           18.664548            11.165741
# 2           0.23          0.21           19.641970            11.160892
# 3           0.23          0.21           19.641970            11.160892
# 4           0.31          0.13           18.664548            11.165741
# 5           0.31          0.13           19.641970            11.160892
# 6           0.20          0.21           17.861534            10.389600
# 7           0.20          0.21           17.861534            10.389600
# 8           0.20          0.21           19.012837            10.966256
# 9           0.20          0.21           19.164353            10.937192

# %%
wisconsin_garden.predict_rpv_embrittlement(test_df)
# Out:
#        preds      ebars
# 0  14.001073   8.925599
# 1  14.001073   8.925599
# 2  27.393063  13.632395
# 3  27.393063  13.632395
# 4  12.671827  11.352390
# 5  21.425608  12.390108
# 6  18.096539  12.848585
# 7  18.096539  12.848585
# 8  28.334789  11.072144
# 9  33.445641  11.628885
