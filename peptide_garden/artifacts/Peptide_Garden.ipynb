# %%
# !pip install garden-ai

# %%
import garden_ai

# %%
gc = garden_ai.GardenClient()

# %%
peptide_garden = gc.get_published_garden('10.23677/cbqt-9z22')

# %%
# First argument is n_seeds. Second argument is sequence_length.
peptide_df = peptide_garden.gen_cpp_seqs(2, 30)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
peptide_df
# Out:
#                                 sequences intensity length relative_Arg  \
# 58               GRPRBGYYCGHYGQNXGLYHXYXF  6.046755     24     0.083333
# 97     AEARXLAKXAAGYPNKKFRAGYRRRKHARLRRRR  6.034852     34     0.294118
# 57               GRPRBGYYCGHYGQNXGLYHXIXF  5.909787     24     0.083333
# 56               GRPRBGYYCGHYGQNXLLYHXIXF  5.895557     24     0.083333
# 55               GRPRBGYYCGHYGQNXLLYHXAXF  5.887436     24     0.083333
# ..                                    ...       ...    ...          ...
# 86       AGAYXLAXAGYLKKRAGYRRRKHRRTRRRRR   3.829347     32      0.34375
# 90       AGAYXLAXAAGYPKKRAGYRRRKHRRLRRRR   3.786379     32       0.3125
# 137  WQLNLLIKGAAALBMKAGLLBLYANYHQRGLLBRP   3.638057     36     0.055556
# 136  WQLNLLIKGAAALBMKAGLLILYANYHQRGLLBRP   3.630357     36     0.055556
# 72         LPAVLLALLAKKKRKRRRRRRRRRRRRRR    3.52823     30          0.5
#
#     relative_charge
# 58         0.147835
# 97         0.405518
# 57          0.14785
# ...
