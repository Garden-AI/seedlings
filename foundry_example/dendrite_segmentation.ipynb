# %% [markdown]
# <img src="https://raw.githubusercontent.com/MLMI2-CSSI/foundry/main/assets/foundry-black.png" width=450>

# %% [markdown]
# # Foundry Dendrite Segmentation Tutorial for Beginners

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MLMI2-CSSI/foundry/blob/main/examples/dendrite-segmentation/dendrite_segmentation.ipynb)

# %% [markdown]
# This introduction uses Foundry to:
#
#
# 1.   Load data from Foundry
# 2.   Build a predictuve U-Net model
# 3. Create augmented data to use with the model
#
# This notebook is set up to run as a [Google Colaboratory](https://colab.research.google.com/notebooks/intro.ipynb#scrollTo=5fCEDCU_qrC0) notebook, which allows you to run python code in the browser, or as a [Jupyter](https://jupyter.org/) notebook, which runs locally on your machine.
#
# The code in the next cell will detect your environment to make sure that only cells that match your environment will run.

# %%
try:
    import google.colab
    no_local_server=True
    no_browser=True
    globus=False
except: # when not in google colab
    no_local_server=False
    no_browser=False
    globus=True

# %% [markdown]
# # Installing Foundry and Other Modules
# First we'll need to install Foundry as well as a few other packages. If you're using Google Colab, this code block will install these packages into the Colab environment.
#
# If you are running locally, it will install these modules onto your machine if you do not already have them. We also have a [requirements file](https://github.com/MLMI2-CSSI/foundry/tree/main/examples/dendrite-segmentation) included with this notebook. You can run `pip install -r requirements.txt` in your terminal to set up your environment locally.

# %%
# %pip install scikit-learn
# %pip install foundry_ml
# %pip install scikit-image
# %pip install tensorflow
# %pip install keras-unet
# %pip install opencv-python

#if in Google Colab, you'll need these pinned
#versions since Colab keeps theirs a few behind
# %pip install pandas==1.2.2 tables==3.6.1

# %% [markdown]
# # Importing Packages
# Now we can import Foundry, which will allow us to load the data.
#
# We'll be using [scikit-image](https://scikit-image.org/) for image processing; [Keras](https://keras.io/) and [TensorFlow](https://www.tensorflow.org/) to create our model; and [pandas](https://pandas.pydata.org/), [OpenCV](https://pypi.org/project/opencv-python/), and [NumPy ](https://numpy.org/)to work with our data.

# %%
from foundry import Foundry
from skimage.io import imshow, imread
from keras_unet.models import custom_unet
import matplotlib.pyplot as plt
from keras_unet.utils import plot_imgs
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from keras_unet.metrics import iou, iou_thresholded
from keras_unet.losses import jaccard_distance
from keras_unet.utils import get_augmented

# %% [markdown]
# # Instantiating Foundry
# To instantiate Foundry, you'll need a [Globus](https://www.globus.org) account. Once you have your account, you can instantiate Foundry using the code below. When you instantiate Foundry locally, be sure to have your Globus endpoint turned on (you can do that with [Globus Connect Personal](https://www.globus.org/globus-connect-personal)). When you instantiate Foundry on Google Colab, you'll be given a link in the cell's output and asked to enter the provided auth code.

# %%
f = Foundry(index="mdf", no_local_server=no_local_server, no_browser=no_browser)

# %% [markdown]
# # Loading the Data
# Now we can use our instance of Foundry to load the data using `f.load()`. Once the data is loaded and accessible, we load the data into the client using `f.load_data()`.

# %%
f.load("foundry_stan_segmentation_v1.1", globus=globus)
# Out:
# Foundry(dc={'identifier': {'identifier': '10.18126/d4kn-cz3p', 'identifierType': 'DOI'}, 'rightsList': [{'rights': 'CC-BY 4.0'}], 'creators': [{'creatorName': 'Stan, Tiberiu', 'affiliations': ['Northwestern University'], 'familyName': 'Stan', 'givenName': 'Tiberiu'}, {'creatorName': 'Thompson, Zach', 'affiliations': ['Northwestern University'], 'familyName': 'Thompson', 'givenName': 'Zach'}, {'creatorName': 'Voorhees, Peter', 'affiliations': ['Northwestern University'], 'familyName': 'Voorhees', 'givenName': 'Peter'}], 'subjects': [{'subject': 'machine learning'}, {'subject': 'foundry'}, {'subject': 'segmentation'}, {'subject': 'metals and alloys'}], 'publicationYear': 2021, 'publisher': 'Materials Data Facility', 'dates': [{'date': '2021-07-26', 'dateType': 'Accepted'}], 'titles': [{'title': 'Dataset for Semantic Segmentation of Dendrites via Machine Learning'}], 'resourceType': {'resourceTypeGeneral': 'Dataset', 'resourceType': 'Dataset'}}, mdf={'resource_type': 'dataset', 'organizations': ['Foundry'], 'ingest_date': '2021-07-26T18:25:34.286195Z', 'source_id': 'foundry_stan_segmentation_v1.1', 'scroll_id': 0, 'version': 1, 'source_name': 'foundry_stan_segmentation'}, dataset=FoundryDataset(keys=[FoundryKey(key=['train/input'], type='input', filter='', units='', description='input, unlabeled images', classes=None), FoundryKey(key=['train/output'], type='target', filter='', units='', description='target, labeled images', classes=None)], splits=[FoundrySplit(type='train', path='foundry.hdf5', label='train')], data_type=<FoundryDatasetType.hdf5: 'hdf5'>, short_name='segmentation', dataframe=None, task_type=['unsupervised', 'segmentation'], domain=['materials science', 'chemistry'], n_items=30), config=FoundryConfig(dataframe_file='foundry_dataframe.json', data_file='foundry.hdf5', metadata_file='foundry_metadata.json', destination_endpoint=None, local=False, metadata_key='foundry', organization='foundry', local_cache_dir='./data'), dlhub_client=<dlhub_sdk.client.DLHubClient object at 0x0000022F215D9D80>, forge_client=<mdf_forge.forge.Forge object at 0x0000022F6437CF40>, connect_client=<mdf_connect_client.mdfcc.MDFConnectClient object at 0x0000022F215D9660>, transfer_client=<globus_sdk.services.transfer.client.TransferClient object at 0x0000022F215D89A0>, auth_client=<globus_sdk.services.auth.client.base.AuthClient object at 0x0000022F215D96C0>, auths={'openid': <globus_sdk.authorizers.refresh_token.RefreshTokenAuthorizer object at 0x0000022F6437F700>, 'data_mdf': <globus_sdk.authorizers.refresh_token.RefreshTokenAuthorizer object at 0x0000022F6437FDF0>, 'petrel': <globus_sdk.authorizers.refresh_token.RefreshTokenAuthorizer object at 0x0000022F6437E680>, 'dlhub': <globus_sdk.authorizers.refresh_token.RefreshTokenAuthorizer object at 0x0000022F215D8280>, 'https://auth.globus.org/scopes/82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/https': <globus_sdk.authorizers.refresh_token.RefreshTokenAuthorizer object at 0x0000022F215D8190>, 'search': <globus_sdk.services.search.client.SearchClient object at 0x0000022F644510F0>, 'mdf_connect': <globus_sdk.authorizers.refresh_token.RefreshTokenAuthorizer object at 0x0000022F215D81F0>, 'transfer': <globus_sdk.services.transfer.client.TransferClient object at 0x0000022F215D89A0>, 'https://auth.globus.org/scopes/d31d4f5d-be37-4adc-a761-2f716b7af105/action_all': <globus_sdk.authorizers.refresh_token.RefreshTokenAuthorizer object at 0x0000022F215D8910>, 'https://auth.globus.org/scopes/f10a69a9-338c-4e5b-baa1-0dc92359ab47/https': <globus_sdk.authorizers.refresh_token.RefreshTokenAuthorizer object at 0x0000022F215D88E0>, 'https://auth.globus.org/scopes/facd7ccc-c5f4-42aa-916b-a0e270e2c2a9/all': <globus_sdk.authorizers.refresh_token.RefreshTokenAuthorizer object at 0x0000022F215D8970>, 'search_authorizer': <globus_sdk.authorizers.refresh_token.RefreshTokenAuthorizer object at 0x0000022F215D97B0>}, xtract_tokens={'auth_token': 'AgXmm4mJMkvy2kG7rrv2MXEqoQ6qBKnnOMzv2raWv56yvkEgvmTwCwm5WWV3KOn2yJmawJJV1gK9DWh04xjPp ...

# %%
res = f.load_data()
X = res['train']['input']['train/input']
y = res['train']['target']['train/output']

# %% [markdown]
# # Visualizing the Data
#
# Now that we've loaded the data, let's take a look!

# %%
fig, axs = plt.subplots(3,2, figsize=(8,8))
for i in range(3):
    axs[i][0].imshow(X[i])
    axs[i][1].imshow(y[i])

# %% [markdown]
# # Building a Model
# ## Resize to Match UNet
# UNet requires images to be of a size multiple of 32, so we'll resize them here.

# %%
new_size = 32*10 # U-Net requires a multiple of 32

X_r = np.array([cv2.resize(img, dsize=(new_size, new_size)) 
     for img in X])
y_r = np.array([cv2.resize(mask, dsize=(new_size, new_size)) 
     for mask in y])

# %%
y_r.shape
# Out:
# (30, 320, 320, 3)

# %% [markdown]
# ## Create UNet Model

# %%
input_shape = (new_size,new_size,3)

model = custom_unet(input_shape)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 320, 320, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 320, 320, 16  432         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 320, 320, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  spatial_dropout2d (SpatialDrop  (None, 320, 320, 16  0          ['batch_normalization[0][0]']
#  out2D)                         )
#
#  conv2d_1 (Conv2D)              (None, 320, 320, 16  2304        ['spatial_dropout2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 320, 320, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 160, 160, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 160, 160, 32  4608        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 160, 160, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  spatial_dropout2d_1 (SpatialDr  (None, 160, 160, 32  0          ['batch_normalization_2[0][0]']
#  opout2D)                       )
#
#  conv2d_3 (Conv2D)              (None, 160, 160, 32  9216        ['spatial_dropout2d_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 160, 160, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 80, 80, 32)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 80, 80, 64)   18432       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 80, 80, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  spatial_dropout2d_2 (SpatialDr  (None, 80, 80, 64)  0           ['batch_normalization_4[0][0]']
#  opout2D)
#
#  conv2d_5 (Conv2D)              (None, 80, 80, 64)   36864       ['spatial_dropout2d_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 80, 80, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 40, 40, 64)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 40, 40, 128)  73728       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 40, 40, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  spatial_dropout2d_3 (SpatialDr  (None, 40, 40, 128)  0          ['batch_normalization_6[0][0]']
#  opout2D)
#
#  conv2d_7 (Conv2D)              (None, 40, 40, 128)  147456      ['spatial_dropout2d_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 40, 40, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 20, 20, 128)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 20, 20, 256)  294912      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 20, 20, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  spatial_dropout2d_4 (SpatialDr  (None, 20, 20, 256)  0          ['batch_normalization_8[0][0]']
#  opout2D)
#
#  conv2d_9 (Conv2D)              (None, 20, 20, 256)  589824      ['spatial_dropout2d_4[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 20, 20, 256)  1024       ['conv2d_9[0][0]']
#  rmalization)
#
#  conv2d_transpose (Conv2DTransp  (None, 40, 40, 128)  131200     ['batch_normalization_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 40, 40, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 40, 40, 128)  294912      ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 40, 40, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 40, 40, 128)  147456      ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 40, 40, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 80, 80, 64)  32832       ['batch_normalization_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 80, 80, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 80, 80, 64)   73728       ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 80, 80, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 80, 80, 64)   36864       ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 80, 80, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 160, 160, 32  8224       ['batch_normalization_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 160, 160, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'batch_normalization_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 160, 160, 32  18432       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 160, 160, 32  128        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  conv2d_15 (Conv2D)             (None, 160, 160, 32  9216        ['batch_normalization_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 160, 160, 32  128        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 320, 320, 16  2064       ['batch_normalization_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 320, 320, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 320, 320, 16  4608        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 320, 320, 16  64         ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  conv2d_17 (Conv2D)             (None, 320, 320, 16  2304        ['batch_normalization_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 320, 320, 16  64         ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 320, 320, 1)  17          ['batch_normalization_17[0][0]']
#
# ==================================================================================================
# Total params: 1,945,521
# Trainable params: 1,942,577
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %% [markdown]
# # Preview the Segmentation Task

# %%
plot_imgs(org_imgs=X_r, mask_imgs=y_r[:,:,:,0], nm_img_to_plot=3, figsize=6)

# %% [markdown]
# # Create a Generator with Augmented Images

# %%
X_r.shape
# Out:
# (30, 320, 320, 3)

# %%
y_r.shape
# Out:
# (30, 320, 320, 3)

# %%
n_images = 30
y_c = y_r[:,:,:,0]

train_gen = get_augmented(
    X_r, np.reshape(y_c, (n_images, new_size, new_size, 1)), batch_size=2,
    data_gen_args = dict(
        rotation_range=5.,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=30,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='constant'
    ))

# %% [markdown]
# # Preview Augmented Images

# %%
sample_batch = next(train_gen)
xx, yy = sample_batch
print(xx.shape, yy.shape)
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=xx, mask_imgs=yy[:,:,:,0], nm_img_to_plot=2, figsize=6)
# Out:
# (2, 320, 320, 3) (2, 320, 320, 1)

# %% [markdown]
# # Compile Model

# %%
model.compile(
    optimizer="adam", 
    #optimizer=SGD(lr=0.01, momentum=0.99),
    loss='binary_crossentropy',
    #loss=jaccard_distance,
    metrics=[tf.keras.metrics.MeanIoU(num_classes=2)]
)

# %% [markdown]
# # Fit Model

# %%
history = model.fit(
train_gen,
    steps_per_epoch=200,
    epochs=10
)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 180s 877ms/step - loss: 0.3985 - mean_io_u: 0.5280
# Epoch 2/10
# 200/200 [==============================] - 173s 863ms/step - loss: 0.1193 - mean_io_u: 0.6795
# Epoch 3/10
# 200/200 [==============================] - 171s 856ms/step - loss: 0.0660 - mean_io_u: 0.6314
# Epoch 4/10
# 200/200 [==============================] - 171s 855ms/step - loss: 0.0528 - mean_io_u: 0.5762
# Epoch 5/10
# 200/200 [==============================] - 167s 836ms/step - loss: 0.0337 - mean_io_u: 0.5610
# Epoch 6/10
# 200/200 [==============================] - 165s 824ms/step - loss: 0.0284 - mean_io_u: 0.5546
# Epoch 7/10
# 200/200 [==============================] - 163s 814ms/step - loss: 0.0240 - mean_io_u: 0.5369
# Epoch 8/10
# 200/200 [==============================] - 162s 809ms/step - loss: 0.0219 - mean_io_u: 0.5291
# Epoch 9/10
# 200/200 [==============================] - 165s 825ms/step - loss: 0.0203 - mean_io_u: 0.5244
# Epoch 10/10
# 200/200 [==============================] - 174s 868ms/step - loss: 0.0179 - mean_io_u: 0.5231

# %%
model_name = f"./{new_size}x{new_size}-model.h5"
model.save(model_name)

# %%
model = tf.keras.models.load_model(model_name)

# %% [markdown]
# # Run Predict on Images

# %%
y_pred = model.predict(X_r)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# # Check Performance Visually

# %%
plot_imgs(org_imgs=X_r, mask_imgs=y_c, pred_imgs=y_pred, nm_img_to_plot=10)
